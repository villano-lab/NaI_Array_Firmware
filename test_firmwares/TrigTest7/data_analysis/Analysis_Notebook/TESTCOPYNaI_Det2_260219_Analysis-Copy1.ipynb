# %%
#library imports
import sys
import matplotlib as mpl
from matplotlib import pyplot as plt
plt.style.use('../mplstyles/stylelib/standard.mplstyle')
import numpy as np
import pandas as pds

# %%
#2/19 data
cosmics = pds.read_csv("../../cosmics_data/cosmics_NaI_Det2_260219.txt", skiprows=1, \
                         names=['Label','junk', 'BinHigh','BinLow','Counts'], \
                         sep='\s+',encoding='utf_16')
#print(cosmics)
x = np.asarray(cosmics["BinLow"])
y = np.asarray(cosmics["Counts"])
#why do the same commands work for xy,x1y1,x2y2, etc.? 
#I would expect to have to specify which file x and y are pulling from, unless it does that automatically by order of code lines

# %%
#2/16 data
cosmics = pds.read_csv("../../cosmics_data/cosmics_NaI_Det2_260216.txt", skiprows=1, \
                         names=['Label','junk', 'BinHigh','BinLow','Counts'], \
                         sep='\s+',encoding='utf_16')
#print(cosmics)
x1 = np.asarray(cosmics["BinLow"])
y1 = np.asarray(cosmics["Counts"])

# %%
#2/12 data
cosmics = pds.read_csv("../../cosmics_data/cosmics_NaI_Det2_260212.txt", skiprows=1, \
                         names=['Label','junk', 'BinHigh','BinLow','Counts'], \
                         sep='\s+',encoding='utf_16')
#print(cosmics)
x2 = np.asarray(cosmics["BinLow"])
y2 = np.asarray(cosmics["Counts"])

# %%
#2/09 data
cosmics = pds.read_csv("../../cosmics_data/cosmics_NaI_Det2_260209.txt", skiprows=1, \
                         names=['Label','junk', 'BinHigh','BinLow','Counts'], \
                         sep='\s+',encoding='utf_16')
#print(cosmics)
x3 = np.asarray(cosmics["BinLow"])
y3 = np.asarray(cosmics["Counts"])

# %%
#2/23 data
cosmics = pds.read_csv("../../cosmics_data/cosmics_NaI_Det2_TestSettings_260223.txt", skiprows=1, \
                         names=['Label','junk', 'BinHigh','BinLow','Counts'], \
                         sep='\s+',encoding='utf_16')
#print(cosmics)
x4 = np.asarray(cosmics["BinLow"])
y4 = np.asarray(cosmics["Counts"])

# %%
#2/26 data

# %%
#plot setup
fig, axs = plt.subplots(1,1,figsize=(10,8))
ax1 = axs
    
ax1.step(x, y)
ax1.step(x1,y1)
ax1.step(x2,y2)
ax1.step(x3,y3)
    
ax1.set_xlim(2600, 2850)
ax1.set_ylim(0,2350)

ax1.set_xlabel("Channels", fontsize=25)
ax1.set_ylabel("Counts", fontsize=25)

ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
#ax1.legend(loc=1,prop={'size':20})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
plt.show()
    
#change colormap here !!!
#plt.savefig(f'figures/Ba_{title}_{cmap1}.png')

#Think of other ways to manipulate data than just to visualize
#Fiure out how to normalize data graphs with different number of entires but similar shapes
#Figure out how to make an expected data graph based on the geometry of the detector
#Also see if can normalize data to that shape to see particle energy not just interacting length and learn about weird data hmup

# %%
#plot 2 setup (with data from other settings)
fig, axs = plt.subplots(1,1,figsize=(10,8))
ax1 = axs
    
ax1.step(x, y)
ax1.step(x1,y1)
ax1.step(x2,y2)
ax1.step(x3,y3)
ax1.step(x4,y4)
    
ax1.set_xlim(00, 2850)
ax1.set_ylim(0,2350)

ax1.set_xlabel("Channels", fontsize=25)
ax1.set_ylabel("Counts", fontsize=25)

ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
#ax1.legend(loc=1,prop={'size':20})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
plt.show()

#Does the new data from 2/23+2/26 show that the data was oversaturated before, and this is more physically accurate data?
#Is the central hump from this data the same as we saw in the saturated data? What about the hump at the end?
    #Does that show the probability curve of muons interacting at different angles and distance sin the detector?
    #Again what about the anomaly at the end, more saturation?

#Should we try calibration by known radiocative material, and try lowering the voltage anymore or expanding the trigger range?
