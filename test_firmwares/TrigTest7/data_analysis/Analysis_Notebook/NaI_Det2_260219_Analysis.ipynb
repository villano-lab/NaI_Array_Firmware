# %%
#we may need some code in the ../python directory and/or matplotlib styles
import sys
sys.path.append('../python/')

#matplotlib for plotting
import matplotlib as mpl
from matplotlib import pyplot as plt
plt.style.use('../mplstyles/stylelib/standard.mplstyle')

#other computational libraries
import numpy as np

# %%
import pandas as pds

# %%
cosmics = pds.read_csv("../../cosmics_data/cosmics_NaI_Det2_260219.txt", skiprows=1, \
                         names=['Label','junk', 'BinHigh','BinLow','Counts'], \
                         sep='\s+',encoding='utf_16')
print(cosmics)
# Out:
#         Label  junk  BinHigh  BinLow  Counts
# 0      Subset     1        2       1       0
# 1      Subset     1        3       2       0
# 2      Subset     1        4       3       0
# 3      Subset     1        5       4       0
# 4      Subset     1        6       5       0
# ...       ...   ...      ...     ...     ...
# 16378  Subset     1    16380   16379       0
# 16379  Subset     1    16381   16380       0
# 16380  Subset     1    16382   16381       0
# 16381  Subset     1    16383   16382       0
# 16382  Subset     1    16384   16383       0
#
# [16383 rows x 5 columns]

# %%
x = np.asarray(cosmics["BinLow"])
y = np.asarray(cosmics["Counts"])

# %%
cosmics = pds.read_csv("../../cosmics_data/cosmics_NaI_Det2_260216.txt", skiprows=1, \
                         names=['Label','junk', 'BinHigh','BinLow','Counts'], \
                         sep='\s+',encoding='utf_16')
print(cosmics)
# Out:
#         Label  junk  BinHigh  BinLow  Counts
# 0      Subset     1        2       1       0
# 1      Subset     1        3       2       0
# 2      Subset     1        4       3       0
# 3      Subset     1        5       4       0
# 4      Subset     1        6       5       0
# ...       ...   ...      ...     ...     ...
# 16378  Subset     1    16380   16379       0
# 16379  Subset     1    16381   16380       0
# 16380  Subset     1    16382   16381       0
# 16381  Subset     1    16383   16382       0
# 16382  Subset     1    16384   16383       0
#
# [16383 rows x 5 columns]

# %%
x1 = np.asarray(cosmics["BinLow"])
y1 = np.asarray(cosmics["Counts"])

# %%
cosmics = pds.read_csv("../../cosmics_data/cosmics_NaI_Det2_260212.txt", skiprows=1, \
                         names=['Label','junk', 'BinHigh','BinLow','Counts'], \
                         sep='\s+',encoding='utf_16')
print(cosmics)
# Out:
#         Label  junk  BinHigh  BinLow  Counts
# 0      Subset     1        2       1       0
# 1      Subset     1        3       2       0
# 2      Subset     1        4       3       0
# 3      Subset     1        5       4       0
# 4      Subset     1        6       5       0
# ...       ...   ...      ...     ...     ...
# 16378  Subset     1    16380   16379       0
# 16379  Subset     1    16381   16380       0
# 16380  Subset     1    16382   16381       0
# 16381  Subset     1    16383   16382       0
# 16382  Subset     1    16384   16383       0
#
# [16383 rows x 5 columns]

# %%
x2 = np.asarray(cosmics["BinLow"])
y2 = np.asarray(cosmics["Counts"])

# %%
cosmics = pds.read_csv("../../cosmics_data/cosmics_NaI_Det2_260209.txt", skiprows=1, \
                         names=['Label','junk', 'BinHigh','BinLow','Counts'], \
                         sep='\s+',encoding='utf_16')
print(cosmics)
# Out:
#         Label  junk  BinHigh  BinLow  Counts
# 0      Subset     1        2       1       0
# 1      Subset     1        3       2       0
# 2      Subset     1        4       3       0
# 3      Subset     1        5       4       0
# 4      Subset     1        6       5       0
# ...       ...   ...      ...     ...     ...
# 16378  Subset     1    16380   16379       0
# 16379  Subset     1    16381   16380       0
# 16380  Subset     1    16382   16381       0
# 16381  Subset     1    16383   16382       0
# 16382  Subset     1    16384   16383       0
#
# [16383 rows x 5 columns]

# %%
x3 = np.asarray(cosmics["BinLow"])
y3 = np.asarray(cosmics["Counts"])

# %%
# # creating 2D histogram of qi vs pt to visualize ER and NR bands
fig, axs = plt.subplots(1,1,figsize=(10,8))
ax1 = axs
    
ax1.step(x, y)
ax1.step(x1,y1)
ax1.step(x2,y2)
ax1.step(x3,y3)
    
ax1.set_xlim(500, 3000) #in pairs
ax1.set_ylim(0,2500) #

ax1.set_xlabel("Channels", fontsize=25)
ax1.set_ylabel("Counts", fontsize=25)

ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
#ax1.legend(loc=1,prop={'size':20})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
plt.show()
    
#change colormap here !!!
#plt.savefig(f'figures/Ba_{title}_{cmap1}.png')
