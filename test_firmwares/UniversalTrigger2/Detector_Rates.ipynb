# %% [markdown]
# # Detector Rates
# The purpose of this notebook is to compare a scan over the same window (lower threshold 5000) for different subsets of the detector array.

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import InterpolatedUnivariateSpline as interp

# %%
#Import data
data = pd.read_csv ("data/scanrate_06022022_3.csv")
threshold = data.iloc[:,0]
rate = data.iloc[:,1]

rate = rate[threshold > 220]
threshold = threshold[threshold > 220]

# %%
plt.figure(figsize=(16,9))

plt.scatter(threshold,rate)


plt.xlabel("Threshold",size=20)
plt.ylabel("Rate (Hz)",size=20)
plt.title("Trigger Rate on Background vs Lower Threshold",size=30)
plt.rc('xtick', labelsize=16) #fontsize of the x tick labels
plt.rc('ytick', labelsize=16) #fontsize of the y tick labels
plt.yscale('log')
plt.xlim(150)
#plt.ylim(0)

#plt.legend(fontsize=18,loc='upper left')
plt.show()

# %%
diffs = np.zeros(len(threshold))
for i,n in enumerate(rate):
    try:
        diffs[i] = rate[i-1] - n
    except KeyError:
        diffs[i] = np.nan

# %%
plt.figure(figsize=(16,9))

plt.scatter(threshold,diffs)


plt.xlabel("Threshold",size=20)
plt.ylabel("Rate (Hz)",size=20)
plt.title("Difference in Trigger Rate on Background vs Lower Threshold",size=30)
plt.rc('xtick', labelsize=16) #fontsize of the x tick labels
plt.rc('ytick', labelsize=16) #fontsize of the y tick labels
#plt.yscale('log')
#plt.xlim(5000)
#plt.ylim(0)
plt.axvline(700)
plt.axvline(220)
plt.axvline(880)
plt.axvline(1940)
plt.axvline(2650)
point = [880,511]
point2= [1940,1274]
#plt.legend(fontsize=18,loc='upper left')
plt.show()

# %%
plt.figure(figsize=(16,9))

plt.scatter(threshold,diffs)


plt.xlabel("Threshold",size=20)
plt.ylabel("Rate (Hz)",size=20)
plt.title("Difference in Trigger Rate on Background vs Lower Threshold",size=30)
plt.rc('xtick', labelsize=16) #fontsize of the x tick labels
plt.rc('ytick', labelsize=16) #fontsize of the y tick labels
#plt.yscale('log')
#plt.xlim(5000)
#plt.ylim(0)
plt.axvline(700)
plt.axvline(220)
plt.axvline(880)
plt.axvline(1940)
plt.axvline(2650)
point = [880,511]
point2= [1940,1274]
#plt.legend(fontsize=18,loc='upper left')
plt.show()

# %%
plt.figure(figsize=(16,9))

plt.scatter(threshold,diffs)


plt.xlabel("Threshold",size=20)
plt.ylabel("Rate (Hz)",size=20)
plt.title("Difference in Trigger Rate on Background vs Lower Threshold",size=30)
plt.rc('xtick', labelsize=16) #fontsize of the x tick labels
plt.rc('ytick', labelsize=16) #fontsize of the y tick labels
#plt.yscale('log')
#plt.xlim(5000)
#plt.ylim(0)
plt.axvline(700)
plt.axvline(220)
plt.axvline(880)
plt.axvline(1940)
plt.axvline(2650)
point = [880,511]
point2= [1940,1274]
#plt.legend(fontsize=18,loc='upper left')
plt.show()

# %%
plt.plot(point[0],point[1],"o")
plt.plot(point2[0],point2[1],"o")

m = (point2[1] - point[1])/(point2[0]-point[0])
b = point2[1] - m*point2[0]
def y(x):
    return m*x+b
np.arange(500,2000)
x = np.arange(500,2000)
plt.plot(x,y(x))
print ((3000 - b)/(m))
y(2650)
# Out:
# 4337.850589777196
# 1785.066037735849

# %%
print(len(diffs))
print(len(threshold))

# %%
interpolated = interp(threshold,rate)
derivspline = interpolated.derivative()
derivative = - derivspline(threshold)
#print(len(derivative),len(threshold))

# %%
plt.figure(figsize=(16,9))

plt.scatter(threshold,derivative)


plt.xlabel("Threshold",size=20)
plt.ylabel("Rate (Hz)",size=20)
plt.title("Derivative of Trigger Rate on Background vs Lower Threshold",size=30)
plt.rc('xtick', labelsize=16) #fontsize of the x tick labels
plt.rc('ytick', labelsize=16) #fontsize of the y tick labels
#plt.yscale('log')
#plt.xlim(5000)
#plt.ylim(0)

#plt.legend(fontsize=18,loc='upper left')
plt.show()

# %%
#Import data
data = pd.read_csv ("data/scanwindow_06022022_2.csv")
threshold = data.iloc[:,0]
rate = data.iloc[:,1]

rate = rate[threshold > 220]
threshold = threshold[threshold > 220]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9568/4201694686.py in <module>
#       9 plt.rc('xtick', labelsize=16) #fontsize of the x tick labels
#      10 plt.rc('ytick', labelsize=16) #fontsize of the y tick labels
# ---> 11 plt.yscale('lin')#Import data
#      12 data = pd.read_csv ("data/scanwindows1785.csv")
#      13 threshold = data.iloc[:,0]
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in yscale(value, **kwargs)
#    3314 @_copy_docstring_and_deprecators(Axes.set_yscale)
#    3315 def yscale(value, **kwargs):
# -> 3316     return gca().set_yscale(value, **kwargs)
#    3317
#    3318
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_yscale(self, value, **kwargs)
#    3936         g = self.get_shared_y_axes()
#    3937         for ax in g.get_siblings(self):
# -> 3938             ax.yaxis._set_scale(value, **kwargs)
#    3939             ax._update_transScale()
#    3940             ax.stale = True
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _set_scale(self, value, **kwargs)
#     742     def _set_scale(self, value, **kwargs):
#     743         if not isinstance(value, mscale.ScaleBase):
# --> 744             self._scale = mscale.scale_factory(value, self, **kwargs)
#     745         else:
#     746             self._scale = value
#
# ~\anaconda3\lib\site-packages\matplotlib\scale.py in scale_factory(scale, axis, **kwargs)
#     629     """
#     630     scale = scale.lower()
# --> 631     _api.check_in_list(_scale_mapping, scale=scale)
#     632     return _scale_mapping[scale](axis, **kwargs)
#     633
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py in check_in_list(_values, _print_supported_values, **kwargs)
#     124         if val not in values:
#     125             if _print_supported_values:
# --> 126                 raise ValueError(
#     127                     f"{val!r} is not a valid value for {key}; "
#     128                     f"supported values are {', '.join(map(repr, values))}")
#
# ValueError: 'lin' is not a valid value for scale; supported values are 'linear', 'log', 'symlog', 'logit', 'function', 'functionlog'

# %%
#Import data
data = pd.read_csv ("data/scanwindows1785.csv")
threshold = data.iloc[:,0]
rate = data.iloc[:,1]

rate = rate[threshold > 220]
threshold = threshold[threshold > 220]

# %%
plt.figure(figsize=(16,9))

plt.scatter(threshold,rate)


plt.xlabel("Threshold",size=20)
plt.ylabel("Rate (Hz)",size=20)
plt.title("Trigger Rate on Background vs Upper Threshold",size=30)
plt.rc('xtick', labelsize=16) #fontsize of the x tick labels
plt.rc('ytick', labelsize=16) #fontsize of the y tick labels
#plt.yscale('lin')#Import data
data = pd.read_csv ("data/scanwindows1785.csv")
threshold = data.iloc[:,0]
rate = data.iloc[:,1]

rate = rate[threshold > 220]
threshold = threshold[threshold > 220]
plt.xlim(150)
#plt.ylim(0)

#plt.legend(fontsize=18,loc='upper left')
plt.show()
